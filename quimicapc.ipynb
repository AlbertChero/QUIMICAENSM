# %% [markdown]
# <a href="https://colab.research.google.com/github/AlbertChero/QUIMICAENSM/blob/main/quimicapc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install drawdata

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# LEY DE BOYLE

# %%
from drawdata import draw_scatter,draw_histogram,draw_line
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# LEY DE BOYLE

# %%
ley_boyle=pd.read_csv('dboyle.csv')
ley_boyle
# Out:
#               x           y  z
# 0     34.934261  404.376148  a
# 1     56.826992  442.564264  a
# 2     93.678714  441.000686  a
# 3    122.616987  399.475703  a
# 4     74.452498  451.318448  a
# ..          ...         ... ..
# 128  605.469272   69.488708  a
# 129  594.822395   66.807660  a
# 130  623.022015   58.240033  a
# 131  634.682564   76.182345  a
# 132  641.943922  112.358786  a
#
# [133 rows x 3 columns]

# %%
plt.scatter(1/ley_boyle["x"],ley_boyle["y"])

# %%
def RegLin (LX, LY):
  sumX = 0
  sumY = 0
  sumXY = 0
  sumXcuadrado = 0
  for elemento in LX:
    sumX += elemento
    sumXcuadrado = elemento**2
  for elemento in LY:
    sumY += elemento
  i = 0
  for elemento in LX:
    sumXY = LX[i]*LY[i]
    i+=1
  p = i

  m = (((p*sumXY)-(sumX*sumY))/((p*sumXcuadrado)-(sumX*sumX)))
  b = (((sumXcuadrado*sumY)-(sumX*sumXY))/((p*sumXcuadrado)-(sumX*sumX)))
  return f"{round(m,1)}x + {round(b,1)}"
print("p =", RegLin(ley_boyle["x"], ley_boyle["y"]))
# Out:
# p = 0.9x + -9.0

# %% [markdown]
# LEY DE CHARLES

# %%
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
charles_law=pd.read_csv('charleslaw.csv')
charles_law
# Out:
#               x           y  z
# 0    136.887492   45.038137  a
# 1    158.198664   -2.331699  a
# 2    146.743743   64.870076  a
# 3    150.120309   78.563087  a
# 4    166.492759   59.009522  a
# ..          ...         ... ..
# 194  474.537818  410.451625  a
# 195  526.328522  370.448468  a
# 196  521.894374  475.461769  a
# 197  536.707103  408.213141  a
# 198  523.368123  378.098335  a
#
# [199 rows x 3 columns]

# %%
plt.scatter(1/charles_law["x"],charles_law["y"])

# %%
def RegLin (LX, LY):
  sumX = 0
  sumY = 0
  sumXY = 0
  sumXcuadrado = 0
  for elemento in LX:
    sumX += elemento
    sumXcuadrado = elemento**2
  for elemento in LY:
    sumY += elemento
  i = 0
  for elemento in LX:
    sumXY = LX[i]*LY[i]
    i+=1
  p = i

  m = (((p*sumXY)-(sumX*sumY))/((p*sumXcuadrado)-(sumX*sumX)))
  b = (((sumXcuadrado*sumY)-(sumX*sumXY))/((p*sumXcuadrado)-(sumX*sumX)))
  return f"{round(m,1)}x + {round(b,1)}"
print("p =", RegLin(charles_law["x"], charles_law["y"]))
# Out:
# p = 0.7x + -0.0

# %% [markdown]
# LEY DE GAY LUSSAC

# %%
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
lussac_law=pd.read_csv('lussacslaw.csv')
lussac_law
# Out:
#               x           y  z
# 0    140.816061  100.880859  a
# 1     97.051383   29.725669  a
# 2    156.167717   45.387509  a
# 3    153.698911   89.430919  a
# 4    119.884880   68.733119  a
# ..          ...         ... ..
# 185  529.478654  410.420616  a
# 186  512.231949  441.530913  a
# 187  509.084147  453.587451  a
# 188  493.379615  462.588283  a
# 189  488.195249  484.010262  a
#
# [190 rows x 3 columns]

# %%
plt.scatter(1/lussac_law["x"],lussac_law["y"])

# %%
def RegLin (LX, LY):
  sumX = 0
  sumY = 0
  sumXY = 0
  sumXcuadrado = 0
  for elemento in LX:
    sumX += elemento
    sumXcuadrado = elemento**2
  for elemento in LY:
    sumY += elemento
  i = 0
  for elemento in LX:
    sumXY = LX[i]*LY[i]
    i+=1
  p = i

  m = (((p*sumXY)-(sumX*sumY))/((p*sumXcuadrado)-(sumX*sumX)))
  b = (((sumXcuadrado*sumY)-(sumX*sumXY))/((p*sumXcuadrado)-(sumX*sumX)))
  return f"{round(m,1)}x + {round(b,1)}"
print("p =", RegLin(lussac_law["x"], lussac_law["y"]))
# Out:
# p = 0.8x + 0.8

# %% [markdown]
# Grafico numero de moleculas vs velocidad molecular (K)

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
grafico1=pd.read_csv('molvsvK.csv')
grafico1
# Out:
#          x      y  z
# 0    0.000  0.092  a
# 1    0.025  0.144  a
# 2    0.050  0.202  a
# 3    0.075  0.254  a
# 4    0.100  0.312  a
# ..     ...    ... ..
# 115  0.875  0.096  c
# 116  0.900  0.064  c
# 117  0.925  0.054  c
# 118  0.950  0.048  c
# 119  0.975  0.038  c
#
# [120 rows x 3 columns]

# %%
plt.plot(grafico1["x"],grafico1["y"])

# %% [markdown]
# Grafico numero de moleculas vs velocidad molecular (g/mol)

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
grafico2=pd.read_csv('molvsvM.csv')
grafico2
# Out:
#          x      y  z
# 0    0.000  0.000  a
# 1    0.025  0.068  a
# 2    0.050  0.168  a
# 3    0.075  0.252  a
# 4    0.100  0.586  a
# ..     ...    ... ..
# 115  0.875  0.098  c
# 116  0.900  0.084  c
# 117  0.925  0.076  c
# 118  0.950  0.054  c
# 119  0.975  0.054  c
#
# [120 rows x 3 columns]

# %%
plt.plot(grafico2["x"],grafico2["y"])

# %%
url="https://es.wikipedia.org/wiki/Ley_de_Boyle-Mariotte#:~:text=La%20ley%20de%20Boyle%20es,la%20temperatura%20se%20mantiene%20constante."
grafico3=pd.read_html(url)
grafico3[2]
# Out:
#     ×  P (atm)  V (L)  P · V
# 0 NaN        5     60     30
# 1 NaN       10     30     30
# 2 NaN       15     20     30
# 3 NaN       20     15     30
# 4 NaN       25     12     30
# 5 NaN       30     10     30

# %%
#el cuadro presentado es el experimetno de Mariotte, en este se intenta expresar que a mayor presion menor volumen en el contenedor
Presion = [5,10,15,20,25,30]
volumen = [60,30,20,15,12,10]

plt.bar(Presion,volumen)
plt.show()
